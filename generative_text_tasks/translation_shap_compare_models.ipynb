# %% [markdown]
# We aim to clarify a **text generation** model (whether open-source or not) by drawing parallels with another open-source generation model. This approach is similar to **Lime**'s use of a simple model to explain the decision-making process of a complex model. Additionally, integrated gradients highlights the importance of **implementation invariance**, meaning that if two models perform similarly, their performance should also be similar.
#
# This method is useful for explaining generative AI text models, but at least one of the models being compared must be open-source. The models should also **be fine-tuned using similar datasets for the same tasks**. In this notebook, we list three text-generation models for English to German translation and explain them using the SHAP package. If a non-open-source model like ChatGPT performs similarly for the same translation task, the weights of its inputs should be similar as well.

# %%
import warnings
warnings.filterwarnings("ignore", message=".*The 'nopython' keyword.*")

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import shap

# %% [markdown]
# **T5**
# https://huggingface.co/t5-base

# %%
model_name = "t5-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

explainer = shap.Explainer(model, tokenizer)
shap_values = explainer(["Translate from English to German: Would you like some coffee?"])
shap.plots.text(shap_values)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
# Downloading pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   0%|          | 0/182 [00:00<?, ?it/s]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_txjmjtzsefltqiejcjve = '_tp_txjmjtzsefltqiejcjve_output_0';
#     document._zoom_txjmjtzsefltqiejcjve = undefined;
#     function _output_onclick_txjmjtzsefltqiejcjve(i) {
#         var next_id = undefined;
#
#         if (document._zoom_txjmjtzsefltqiejcjve !== undefined) {
#             document.getElementById(document._zoom_txjmjtzsefltqiejcjve+ '_zoom').style.display = 'none';
#
#             if (document._zoom_txjmjtzsefltqiejcjve === '_tp_txjmjtzsefltqiejcjve_output_' + i) {
#                 document.getElementById(document._zoom_txjmjtzsefltqiejcjve).style.display = 'block';
#                 document.getElementById(document._zoom_txjmjtzsefltqiejcjve+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_txjmjtzsefltqiejcjve).style.display = 'none';
#                 document.getElementById(document._zoom_txjmjtzsefltqiejcjve+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_txjmjtzsefltqiejcjve !== '_tp_txjmjtzsefltqiejcjve_output_' + i) {
#             next_id = '_tp_txjmjtzsefltqiejcjve_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_txjmjtzsefltqiejcjve = next_id;
#     }
#     function _output_onmouseover_txjmjtzsefltqiejcjve(i, el) {
#         if (document._zoom_txjmjtzsefltqiejcjve !== undefined) { return; }
#         if (document._hover_txjmjtzsefltqiejcjve !== undefined) {
#             document.getElementById(document._hover_txjmjtzsefltqiejcjve + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_txjmjtzsefltqiejcjve).style.display = 'none';
#         }
#         document.getElementById('_tp_txjmjtzsefltqiejcjve_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_txjmjtzsefltqiejcjve = '_tp_txjmjtzsefltqiejcjve_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.13289760348583876); border-radius: 3px; padding: 0px" id="_tp_txjmjtzsefltqiejcjve_output_0_name"
#     onclick="_output_onclick_txjmjtzsefltqiejcjve(0)"
#     onmouseover="_output_onmouseover_txjmjtzsefltqiejcjve(0, this);">Möchte</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.5822142998613588); border-radius: 3px; padding: 0px" id="_tp_txjmjtzsefltqiejcjve_output_1_name"
#     onclick="_output_onclick_txjmjtzsefltqiejcjve(1)"
#     onmouseover="_output_onmouseover_txjmjtzsefltqiejcjve(1, this);">n</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_txjmjtzsefltqiejcjve_output_2_name"
#     onclick="_output_onclick_txjmjtzsefltqiejcjve(2)"
#     onmouseover="_output_onmouseover_txjmjtzsefltqiejcjve(2, this);">Sie</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.25113883937413345); border-radius: 3px; padding: 0px" id="_tp_txjmjtzsefltqiejcjve_output_3_name"
#     onclick="_output_onclick_txjmjtzsefltqiejcjve(3)"
#     onmouseover="_output_onmouseover_txjmjtzsefltqiejcjve(3, this);">Kaffee</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.12501485442661905); border-radius: 3px; padding: 0px" id="_tp_txjmjtzsefltqiejcjve_output_4_name"
#     onclick="_output_onclick_txjmjtzsefltqiejcjve(4)"
#     onmouseover="_output_onmouseover_txjmjtzsefltqiejcjve(4, this);">?</div><br><br><div id='_tp_txjmjtzsefltqiejcjve_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.263094448052634%" y1="33" x2="49.263094448052634%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.263094448052634%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-10</text><line x1="23.37587728687972%" y1="33" x2="23.37587728687972%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="23.37587728687972%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-20</text><line x1="75.15031160922555%" y1="33" x2="75.15031160922555%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="75.15031160922555%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="6.9713030467372645%" y1="33" x2="6.9713030467372645%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="6.9713030467372645%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-26.3369</text><text x="6.9713030467372645%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-26.3369</text><text x="6.9713030467372645%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="76.68227463123002%" y1="33" x2="76.68227463123002%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="76.68227463123002%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.591784</text><text x="76.68227463123002%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.591784</text><text x="76.68227463123002%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Möchte</tspan>(inputs)</text><rect x="6.971131473163941%" width="69.71114315806606%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="61.20185738532365%" x2="76.68227463123002%" y1="60" y2="60" id="_fb_dalnvhcvekkekwdkruhk_ind_6" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="68.94206600827684%" y="71" font-size="12px" id="_fs_dalnvhcvekkekwdkruhk_ind_6" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">5.98</text><svg x="61.20185738532365%" y="40" height="20" width="15.480417245906366%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">:</text>  </svg></svg><line x1="46.724409076332485%" x2="61.20185738532365%" y1="60" y2="60" id="_fb_dalnvhcvekkekwdkruhk_ind_12" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="53.96313323082806%" y="71" font-size="12px" id="_fs_dalnvhcvekkekwdkruhk_ind_12" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">5.593</text><svg x="46.724409076332485%" y="40" height="20" width="14.477448308991164%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">?</text>  </svg></svg><line x1="36.32170584532481%" x2="46.724409076332485%" y1="60" y2="60" id="_fb_dalnvhcvekkekwdkruhk_ind_7" style="stroke:rgb(255.0, 0.0, 81.08083606031792);st

# %% [markdown]
# **Helsinki-NLP/opus-mt-en-de**
# https://huggingface.co/Helsinki-NLP/opus-mt-en-de

# %%
model_name = "Helsinki-NLP/opus-mt-en-de"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

explainer = shap.Explainer(model, tokenizer)
shap_values = explainer(["Would you like some coffee?"])
shap.plots.text(shap_values)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_fvwalfnieydidpxxyvkj = '_tp_fvwalfnieydidpxxyvkj_output_0';
#     document._zoom_fvwalfnieydidpxxyvkj = undefined;
#     function _output_onclick_fvwalfnieydidpxxyvkj(i) {
#         var next_id = undefined;
#
#         if (document._zoom_fvwalfnieydidpxxyvkj !== undefined) {
#             document.getElementById(document._zoom_fvwalfnieydidpxxyvkj+ '_zoom').style.display = 'none';
#
#             if (document._zoom_fvwalfnieydidpxxyvkj === '_tp_fvwalfnieydidpxxyvkj_output_' + i) {
#                 document.getElementById(document._zoom_fvwalfnieydidpxxyvkj).style.display = 'block';
#                 document.getElementById(document._zoom_fvwalfnieydidpxxyvkj+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_fvwalfnieydidpxxyvkj).style.display = 'none';
#                 document.getElementById(document._zoom_fvwalfnieydidpxxyvkj+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_fvwalfnieydidpxxyvkj !== '_tp_fvwalfnieydidpxxyvkj_output_' + i) {
#             next_id = '_tp_fvwalfnieydidpxxyvkj_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_fvwalfnieydidpxxyvkj = next_id;
#     }
#     function _output_onmouseover_fvwalfnieydidpxxyvkj(i, el) {
#         if (document._zoom_fvwalfnieydidpxxyvkj !== undefined) { return; }
#         if (document._hover_fvwalfnieydidpxxyvkj !== undefined) {
#             document.getElementById(document._hover_fvwalfnieydidpxxyvkj + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_fvwalfnieydidpxxyvkj).style.display = 'none';
#         }
#         document.getElementById('_tp_fvwalfnieydidpxxyvkj_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_fvwalfnieydidpxxyvkj = '_tp_fvwalfnieydidpxxyvkj_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(30.0, 136.0, 229.0, 0.14078035254505836); border-radius: 3px; padding: 0px" id="_tp_fvwalfnieydidpxxyvkj_output_0_name"
#     onclick="_output_onclick_fvwalfnieydidpxxyvkj(0)"
#     onmouseover="_output_onmouseover_fvwalfnieydidpxxyvkj(0, this);">Möchten</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.8502277678748268); border-radius: 3px; padding: 0px" id="_tp_fvwalfnieydidpxxyvkj_output_1_name"
#     onclick="_output_onclick_fvwalfnieydidpxxyvkj(1)"
#     onmouseover="_output_onmouseover_fvwalfnieydidpxxyvkj(1, this);">Sie</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.09348385818974048); border-radius: 3px; padding: 0px" id="_tp_fvwalfnieydidpxxyvkj_output_2_name"
#     onclick="_output_onclick_fvwalfnieydidpxxyvkj(2)"
#     onmouseover="_output_onmouseover_fvwalfnieydidpxxyvkj(2, this);">einen</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_fvwalfnieydidpxxyvkj_output_3_name"
#     onclick="_output_onclick_fvwalfnieydidpxxyvkj(3)"
#     onmouseover="_output_onmouseover_fvwalfnieydidpxxyvkj(3, this);">Kaffee</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.9369380075262429); border-radius: 3px; padding: 0px" id="_tp_fvwalfnieydidpxxyvkj_output_4_name"
#     onclick="_output_onclick_fvwalfnieydidpxxyvkj(4)"
#     onmouseover="_output_onmouseover_fvwalfnieydidpxxyvkj(4, this);">?</div><br><br><div id='_tp_fvwalfnieydidpxxyvkj_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.866392300139744%" y1="33" x2="49.866392300139744%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.866392300139744%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="37.121751965352%" y1="33" x2="37.121751965352%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="37.121751965352%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-6</text><line x1="24.377111630564254%" y1="33" x2="24.377111630564254%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="24.377111630564254%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8</text><line x1="11.632471295776506%" y1="33" x2="11.632471295776506%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="11.632471295776506%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-10</text><line x1="62.61103263492749%" y1="33" x2="62.61103263492749%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="62.61103263492749%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-2</text><line x1="75.35567296971523%" y1="33" x2="75.35567296971523%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="75.35567296971523%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="88.10031330450298%" y1="33" x2="88.10031330450298%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="88.10031330450298%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="6.633593727662755%" y1="33" x2="6.633593727662755%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="6.633593727662755%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-10.7845</text><text x="6.633593727662755%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-10.7845</text><text x="6.633593727662755%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="72.96951812259097%" y1="33" x2="72.96951812259097%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="72.96951812259097%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-0.374456</text><text x="72.96951812259097%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-0.374456</text><text x="72.96951812259097%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Möchten</tspan>(inputs)</text><rect x="6.633592654187814%" width="66.33592546840316%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="38.58240181020487%" x2="72.96951812259097%" y1="60" y2="60" id="_fb_kyzstenmzdaoqgsblmeb_ind_0" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="55.77595996639792%" y="71" font-size="12px" id="_fs_kyzstenmzdaoqgsblmeb_ind_0" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">5.396</text><svg x="38.58240181020487%" y="40" height="20" width="3

# %% [markdown]
# **Tanhim/translation-En2De**
# https://huggingface.co/Tanhim/translation-En2De

# %%
model_name = "Tanhim/translation-En2De"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

explainer = shap.Explainer(model, tokenizer)
shap_values = explainer(["Would you like some coffee?"])

# %%
shap.plots.text(shap_values)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_xwkukjbcixbqoirrtpza = '_tp_xwkukjbcixbqoirrtpza_output_0';
#     document._zoom_xwkukjbcixbqoirrtpza = undefined;
#     function _output_onclick_xwkukjbcixbqoirrtpza(i) {
#         var next_id = undefined;
#
#         if (document._zoom_xwkukjbcixbqoirrtpza !== undefined) {
#             document.getElementById(document._zoom_xwkukjbcixbqoirrtpza+ '_zoom').style.display = 'none';
#
#             if (document._zoom_xwkukjbcixbqoirrtpza === '_tp_xwkukjbcixbqoirrtpza_output_' + i) {
#                 document.getElementById(document._zoom_xwkukjbcixbqoirrtpza).style.display = 'block';
#                 document.getElementById(document._zoom_xwkukjbcixbqoirrtpza+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_xwkukjbcixbqoirrtpza).style.display = 'none';
#                 document.getElementById(document._zoom_xwkukjbcixbqoirrtpza+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_xwkukjbcixbqoirrtpza !== '_tp_xwkukjbcixbqoirrtpza_output_' + i) {
#             next_id = '_tp_xwkukjbcixbqoirrtpza_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_xwkukjbcixbqoirrtpza = next_id;
#     }
#     function _output_onmouseover_xwkukjbcixbqoirrtpza(i, el) {
#         if (document._zoom_xwkukjbcixbqoirrtpza !== undefined) { return; }
#         if (document._hover_xwkukjbcixbqoirrtpza !== undefined) {
#             document.getElementById(document._hover_xwkukjbcixbqoirrtpza + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_xwkukjbcixbqoirrtpza).style.display = 'none';
#         }
#         document.getElementById('_tp_xwkukjbcixbqoirrtpza_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_xwkukjbcixbqoirrtpza = '_tp_xwkukjbcixbqoirrtpza_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(30.0, 136.0, 229.0, 0.1328976034858387); border-radius: 3px; padding: 0px" id="_tp_xwkukjbcixbqoirrtpza_output_0_name"
#     onclick="_output_onclick_xwkukjbcixbqoirrtpza(0)"
#     onmouseover="_output_onmouseover_xwkukjbcixbqoirrtpza(0, this);">Möchte</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_xwkukjbcixbqoirrtpza_output_1_name"
#     onclick="_output_onclick_xwkukjbcixbqoirrtpza(1)"
#     onmouseover="_output_onmouseover_xwkukjbcixbqoirrtpza(1, this);">st</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.6610417904535549); border-radius: 3px; padding: 0px" id="_tp_xwkukjbcixbqoirrtpza_output_2_name"
#     onclick="_output_onclick_xwkukjbcixbqoirrtpza(2)"
#     onmouseover="_output_onmouseover_xwkukjbcixbqoirrtpza(2, this);">du</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.14078035254505836); border-radius: 3px; padding: 0px" id="_tp_xwkukjbcixbqoirrtpza_output_3_name"
#     onclick="_output_onclick_xwkukjbcixbqoirrtpza(3)"
#     onmouseover="_output_onmouseover_xwkukjbcixbqoirrtpza(3, this);">einen</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.7635175282234107); border-radius: 3px; padding: 0px" id="_tp_xwkukjbcixbqoirrtpza_output_4_name"
#     onclick="_output_onclick_xwkukjbcixbqoirrtpza(4)"
#     onmouseover="_output_onmouseover_xwkukjbcixbqoirrtpza(4, this);">Kaffee</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.7162210338680925); border-radius: 3px; padding: 0px" id="_tp_xwkukjbcixbqoirrtpza_output_5_name"
#     onclick="_output_onclick_xwkukjbcixbqoirrtpza(5)"
#     onmouseover="_output_onmouseover_xwkukjbcixbqoirrtpza(5, this);">?</div><br><br><div id='_tp_xwkukjbcixbqoirrtpza_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="51.22900291189718%" y1="33" x2="51.22900291189718%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.22900291189718%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="38.32773971151375%" y1="33" x2="38.32773971151375%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="38.32773971151375%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-7</text><line x1="25.42647651113032%" y1="33" x2="25.42647651113032%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="25.42647651113032%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-10</text><line x1="12.525213310746892%" y1="33" x2="12.525213310746892%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="12.525213310746892%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-13</text><line x1="64.13026611228061%" y1="33" x2="64.13026611228061%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="64.13026611228061%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1</text><line x1="77.03152931266403%" y1="33" x2="77.03152931266403%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.03152931266403%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="89.93279251304747%" y1="33" x2="89.93279251304747%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.93279251304747%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">5</text><line x1="5.973383017391711%" y1="33" x2="5.973383017391711%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="5.973383017391711%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-14.5235</text><text x="5.973383017391711%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-14.5235</text><text x="5.973383017391711%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="65.7069801963121%" y1="33" x2="65.7069801963121%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="65.7069801963121%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-0.633358</text><text x="65.7069801963121%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-0.633358</text><text x="65.7069801963121%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Möchte</tspan>(inputs)</text><rect x="5.973363601141983%" width="59.733616595170126%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="33.66233423237338%" x2="65.7069801963121%" y1="60" y2="60" id="_fb_yiocggoztevgrtssoomo_ind_0" style="stroke:rgb(255.0, 0.0, 81.0
